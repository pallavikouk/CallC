# %%
import pandas as pd
height=pd.Series([5.3, 6.2,5.8,5.0],index=['Person 1','Person 2','Person 3','Person 4'])
height
# Out:
# Person 1    5.3
# Person 2    6.2
# Person 3    5.8
# Person 4    5.0
# dtype: float64

# %%
weight=pd.Series([65,89,75,60,59],index=['Person 1','Person 2','Person 3','Person 4','Person 5'])
weight
# Out:
# Person 1    65
# Person 2    89
# Person 3    75
# Person 4    60
# Person 5    59
# dtype: int64

# %%
person=pd.DataFrame({'weight':weight,'height':height})
person
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 person=pd.DataFrame({'weight':weight,'height':height})
#       2 person
#
# NameError: name 'weight' is not defined

# %%
type(person)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 type(person)
#
# NameError: name 'person' is not defined

# %%
person.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 person.shape
#
# NameError: name 'person' is not defined

# %%
person.columns
# Out:
# Index(['weight', 'height'], dtype='object')

# %%
person.info
# Out:
# <bound method DataFrame.info of           weight  height
# Person 1      65     5.3
# Person 2      89     6.2
# Person 3      75     5.8
# Person 4      60     5.0
# Person 5      59     NaN>

# %%
person.describe()
# Out:
#           weight    height
# count   5.000000  4.000000
# mean   69.600000  5.575000
# std    12.561847  0.531507
# min    59.000000  5.000000
# 25%    60.000000  5.225000
# 50%    65.000000  5.550000
# 75%    75.000000  5.900000
# max    89.000000  6.200000

# %%
df=pd.read_csv('C:\\Users\\Prasad\\Downloads\\MOMA\\IMDB-Movie-Data.csv')
df.head(9)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df[['Rating','Rank']]
# Out:
#      Rating  Rank
# 0       8.1     1
# 1       7.0     2
# 2       7.3     3
# 3       7.2     4
# 4       6.2     5
# ..      ...   ...
# 995     6.2   996
# 996     5.5   997
# 997     6.2   998
# 998     5.6   999
# 999     5.3  1000
#
# [1000 rows x 2 columns]

# %%
df.iloc[9:15][['Genre','Actors']]
# Out:
#                                                               Genre  \
# Title
# Passengers                                  Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# Hidden Figures                              Biography,Drama,History
# Rogue One                                   Action,Adventure,Sci-Fi
# Moana                                    Animation,Adventure,Comedy
# Colossal                                        Action,Comedy,Drama
#
#                                                                                     Actors
# Title
# Passengers                               Jennifer Lawrence, Chris Pratt, Michael Sheen,...
# Fantastic Beasts and Where to Find Them  Eddie Redmayne, Katherine Waterston, Alison Su...
# Hidden Figures                           Taraji P. Henson, Octavia Spencer, Janelle Mon...
# Rogue One                                Felicity Jones, Diego Luna, Alan Tudyk, Donnie...
# ...

# %%
df[(df['Year']>=2009) & (df['Year']<=2016)&(df['Rating']<6.0)&(df['Revenue (Millions)'] > df['Revenue (Millions)'].quantile(0.95))]
# Out:
#      Rank                       Title                    Genre  \
# 941   942  The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 941                124     4.9  192740              300.52       58.0

# %%
df=pd.read_csv('C:\\Users\\Prasad\\Downloads\\MOMA\\IMDB-Movie-Data.csv')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df[(df['Year']>=2009) & (df['Year']<=2016)&(df['Rating']<6.0)&(df['Revenue (Millions)'] > df['Revenue (Millions)'].quantile(0.95))]
# Out:
#      Rank                       Title                    Genre  \
# 941   942  The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 941                124     4.9  192740              300.52       58.0

# %%
df['Revenue (Millions)']
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
df.groupby('Director')[['Rating']].mean().head()
# Out:
#                      Rating
# Director
# Aamir Khan              8.5
# Abdellatif Kechiche     7.8
# Adam Leon               6.5
# Adam McKay              7.0
# Adam Shankman           6.3

# %%
df.groupby('Year')

# %%
l = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
dfl = pd.DataFrame(l, columns=['a','b','c'])
dfl
# Out:
#    a    b  c
# 0  1  2.0  3
# 1  1  NaN  4
# 2  2  1.0  3
# 3  1  2.0  2

# %%
dfl.groupby(by=['b'],dropna=False).sum()
# Out:
#      a  c
# b
# 1.0  2  3
# 2.0  2  5
# NaN  1  4

# %%
df.groupby(df['Year']>=2016,group_keys=True).apply(lambda x:x)
# Out:
#            Rank                           Title                     Genre  \
# Year
# False 0       1         Guardians of the Galaxy   Action,Adventure,Sci-Fi
#       1       2                      Prometheus  Adventure,Mystery,Sci-Fi
#       26     27         Bahubali: The Beginning    Action,Adventure,Drama
#       36     37                    Interstellar    Adventure,Drama,Sci-Fi
#       39     40                       5- 25- 77              Comedy,Drama
# ...         ...                             ...                       ...
# True  975   976      My Big Fat Greek Wedding 2     Comedy,Family,Romance
#       977   978                   Amateur Night                    Comedy
#       978   979  It's Only the End of the World                     Drama
#       980   981            Miracles from Heaven    Biography,Drama,Family
#       999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                                  Description  \
# Year
# ...

# %%
dfA = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
dfA
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
dfA.groupby('Animal', group_keys=True).apply(lambda x: x)
# Out:
#           Animal  Max Speed
# Animal
# Falcon 0  Falcon      380.0
#        1  Falcon      370.0
# Parrot 2  Parrot       24.0
#        3  Parrot       26.0

# %%
dfA.groupby('Animal')[['Max Speed']].mean().sort_values(['Max Speed'], ascending=False)
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\Prasad\\Downloads\\MOMA\\IMDB-Movie-Data.csv')
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.rename(columns={'Revenue (Millions)':'Revenue_Millions'},inplace=True)
df.columns
# Out:
#             Rank                     Genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   Description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         Director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        Actors  Year  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
#
#             Runtime (Minutes)  Rating   Votes  Revenue_Millions  Metascore
# Title
# ...

# %%
df.columns=[col.lower() for col in df]
df.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime (minutes)', 'rating', 'votes', 'revenue_millions',
#        'metascore'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# rank                   0
# title                  0
# genre                  0
# description            0
# director               0
# actors                 0
# year                   0
# runtime (minutes)      0
# rating                 0
# votes                  0
# revenue_millions     128
# metascore             64
# dtype: int64

# %%
df['revenue_millions']
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: revenue_millions, Length: 1000, dtype: float64

# %%
revenue_mean=df['revenue_millions'].mean()
revenue_mean
# Out:
# 82.95637614678898

# %%
df.fillna(revenue_mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# rank                 0
# title                0
# genre                0
# description          0
# director             0
# actors               0
# year                 0
# runtime (minutes)    0
# rating               0
# votes                0
# revenue_millions     0
# metascore            0
# dtype: int64

# %%
df['genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object

# %%
df['director'].describe()
# Out:
# count             1000
# unique             644
# top       Ridley Scott
# freq                 8
# Name: director, dtype: object

# %%
df['genre'].value_counts().head(34)
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Adventure,Drama        18
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Adventure,Family,Fantasy      14
# Biography,Drama,History       14
# Action,Adventure,Comedy       14
# Biography,Drama               14
# Action,Comedy,Crime           12
# Action,Crime,Thriller         12
# Action,Adventure,Thriller     11
# Horror                        11
# Crime,Drama                   10
# Biography,Crime,Drama          9
# Thriller                       9
# Horror,Mystery,Thriller        9
# Action,Thriller                9
# ...

# %%
df.corr()
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_24440\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        rank      year  runtime (minutes)    rating     votes  \
# rank               1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# year              -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# runtime (minutes) -0.221739 -0.164900           1.000000  0.392214  0.407062
# rating            -0.219555 -0.211219           0.392214  1.000000  0.511537
# votes             -0.283876 -0.411904           0.407062  0.511537  1.000000
# revenue_millions  -0.252996 -0.117562           0.247834  0.189527  0.607941
# metascore         -0.164406 -0.067122           0.183916  0.562225  0.263146
#
#                    revenue_millions  metascore
# ...

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df[df['Rating'] >3]
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df[df['Director'] == "Ridley Scott"]
# Out:
#      Rank                   Title                     Genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            Description      Director  \
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# ...

# %%
def rating_function(x):
    if x>=8.0:
        return 'good'
    else:
        return 'bad'
df['rating_category']=df['Rating'].apply(lambda x: 'good' if x >= 8.0 else 'bad')
df.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore rating_category
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)}) # set font and plot size to be larger

# %%
df.plot(kind='scatter', x='Rating', y='Revenue (Millions)', title='Revenue (millions) vs Rating')
# Out:
# <Axes: title={'center': 'Revenue (millions) vs Rating'}, xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
df['Rating'].plot(kind='hist', title='Rating')
# Out:
# <Axes: title={'center': 'Rating'}, ylabel='Frequency'>

# %%
df['Rating'].plot(kind="box")
# Out:
# <Axes: >

# %%
df.boxplot(column='Revenue (Millions)', by='rating_category')
# Out:
# <Axes: title={'center': 'Revenue (Millions)'}, xlabel='rating_category'>
